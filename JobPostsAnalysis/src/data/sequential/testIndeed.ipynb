# %%
from bs4 import BeautifulSoup
import pandas as pd
import time, requests, argparse, json
from typing import List, Dict, Union, Optional
from config import CONFIG
from logzero import setup_logger

logger = setup_logger(name='jupyterLogger')

# %%
URL = 'http://www.indeed.com/jobs?'
queries = {'q':'data scientist', 'l': 'Houston, TX'}
try:
    page = requests.get(URL, params=queries)
except Exception as e:
    logger.debug(f"Server's response: {page.status_code}")
    logger.error(e)
else:
    if page == None:
        self.logger.error('Not found page')
    else:
        soup = BeautifulSoup(page.text, 'html.parser')
        divs = soup.find_all(name='div', class_='jobsearch-SerpJobCard')

# %%
jobPosts = soup.find_all('div', class_='jobsearch-SerpJobCard')
jobPosts[0]

# %%
print(divs[4])
# Out:
# <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="361555545" data-empn="7186865467086996" data-jk="663258a03501b6ee" id="pj_663258a03501b6ee">
# <style>
# .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}.jasxrefreshcombotst .jobcard_logo img{max-height:2rem;max-width:100%}
# </style>
# <h2 class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0B90vXIBqWgvTqf7OKHeB9p7Zq1kPkqK3vrGjEIBoxh4TqbAfirhCaHiozdLTg_UvD_UoFbaDyN_sZjOrF0ksSUtuV5nt4GpD0WKLXuB5nG3VD1EqCqlC3jxudWFI5uQXfeELg3-ELFObYymfYMBCMlWA9BBpO1rl-m9iHRi3hJtvs7J4wuMJ4OYDETz-XC8wwAInrKDhfubGYu9z1Gdgq1CYB0-nJhXRNygG-Yli-eS1vtgDydczRRMr0kdYjGlepijirT3wPgKyW82iQPVVbh-8UyQd6r86RPkwOFd6GW9Hrc6LGXYPlj84BpxFPnMMgZt34_DbLtcX7b4FzjOyjdaqgTSqjFCLYdQQPYOoRkDsIDApjgzscwJHJHv0LOfuWrFoh43yUw_b0pvN0MK7j4wDQRxmGvBug9UuOfq6RZ6GcZpaWDffMn4fRGbkmx6f8=&amp;p=4&amp;fvj=0&amp;vjs=3" id="sja4" onclick="setRefineByCookie([]); sjoc('sja4', 0); convCtr('SJ'); rclk(this,jobmap[4],true,0);" onmousedown="sjomd('sja4'); clk('sja4'); rclk(this,jobmap[4],0);" rel="noopener nofollow" target="_blank" title="Business Analytics (Data Science) Intern">
# Business Analytics (<b>Data</b> Science) Intern</a>
# </h2>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Hewlett-Packard-Enterprise" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=663258a03501b6ee&amp;jcid=c95831c31635f73c')" rel="noopener" target="_blank">
# Hewlett Packard Enterprise</a></span>
# <span class="ratingsDisplay">
# <a aria-label="Company rating 3.8 out of 5 stars" class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Hewlett-Packard-Enterprise/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Business+Analytics+%28Data+Science%29+Intern&amp;fromjk=663258a03501b6ee&amp;jcid=c95831c31635f73c');" rel="noopener" target="_blank" title="Hewlett Packard Enterprise reviews"></a>
# <span class="ratingsContent">
# 3.8<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </span></div></div></div>

# %%
import re
info =[]
for div in divs:
    temp_info = {}
    for a in div.find_all('a', class_= re.compile(r"jobtitle.*")):
        temp_info['title'] = a.text
        temp_info['summarylinks'] = a['href']
    for name in div.find_all('span', attrs={'class': 'company'}):
        temp_info['name'] = name.text
    for loc in div.find_all('div', class_='location accessible-contrast-color-location'):
        temp_info['location'] = loc.text
    info.append(temp_info)

# %%
info
# Out:
# [{'title': '\nArchitecture Data Scientist',
#   'summarylinks': '/pagead/clk?mo=r&ad=-6NYlbfkN0C4JTuWysBZGWr3ScYyn1q3GP1Wt9Y6KOMkEf9pRAXJOWsVIs1722niEMWH1tX4ZZCGEzLVh4D_WHn1m2gjFAQ6gEvk6nQ2T4G6E7a8_HHJvLlRzGw5I8x3wt2kSN2qIvwPoOZ9r7BYPDF5dqQpISVAh8sy-4wN0Xww_G4WxrTxSfuMosmVxmI4QaK1A-OxpW6yf1MzTKofpLPJFPEX5w3juVgIvhuL25YF3W0m3_ci1JswGGLwP3GOybg8HxGMEKSS_3awkeL0iV6hnVLq45yuwOjzwsA-XP-zVf8-zXhzVHnTKG-h6VKT0yIwY2b2PqiVauguiRZc9sYjMj6aw_ODRCDrVlwcZ8MP3ePLZRF3ZHQn0WjxIgt5K5o7WL6CrsRMPKyHHqZi_3SZifba1wQUPW4PL_XHhhaRplAHyP4H9gqYTjHvLxsVXUYMIjVU0Ch4fyuB_uJK445NBRlR1afWFHcZNH9yKTQd8nhV8LDpLUZgiLeNNoBrxy0bmx8IHikp_5W9pqmTKfNs07mCZQyA7KPt-O8M6JiaA2NiBl7P79_s4FZyj_pwO8OJCxNzpj-4JlBFoveZMnQ782mqZcaqGvMYbMSogUd-xbXQBAx3TTVC-4o3-EATMWadoYNkORmFcqjQijqOPHP3hxz55CwdA7GE2NBvz7Op6nmBC0-tnISjno2yguZqQv1tld36QtmTIRCHl7OLpjZQ_8AKy2LBOPMzURvvkpWtYZSc8UY29yJK13QrBLWMlavWwIfw_SwJJf2IdpUO3u7lnBQac6oZEgzjYNMcQPKSp3bYDMa9axe-jf5b5JL7TEV0OC0WZ2IxeZU5a9LMoh5u1-bNr2z2bXsWpyIxIJ6si_cSpkSdPHBY0nN4zSwjrST-mReb2a9NFycUnqwyQrVJnHgxW5K19qMvQhXEd-cf-Hp3CIa-WKIllLXKHnQ7YMoWub4lg6M=&p=0&fvj=0&vjs=3',
#   'name': '\n\nHP'},
#  {'title': '\nData Scientist Master - Remote',
QaK1A-OxpW6yf1MzTKofpLPJFPEX5w3juVgIvhuL25YF3W0m3_ci1JswGGLwP3GOybg8HxGMEKSS_3awkeL0iV6hnVLq45yuwOjzwsA-XP-zVf8-zXhzVHnTKG-h6VKT0yIwY2b2PqiVauguiRZc9sYjMj6aw_ODRCDrVlwcZ8MP3ePLZRF3ZHQn0WjxIgt5K5o7WL6CrsRMPKyHHqZi_3SZifba1wQUPW4PL_XHhhaRplAHyP4H9gqYTjHvLxsVXUYMIjVU0Ch4fyuB_uJK445NBRlR1afWFHcZNH9yKTQd8nhV8LDpLUZgiLeNNoBrxy0bmx8IHikp_5W9pqmTKfNs07mCZQyA7KPt-O8M6JiaA2NiBl7P79_s4FZyj_pwO8OJCxNzpj-4JlBFoveZMnQ782mqZcaqGvMYbMSogUd-xbXQBAx3TTVC-4o3-EATMWadoYNkORmFcqjQijqOPHP3hxz55CwdA7GE2NBvz7Op6nmBC0-tnISjno2yguZqQv1tld36QtmTIRCHl7OLpjZQ_8AKy2LBOPMzURvvkpWtYZSc8UY29yJK13QrBLWMlavWwIfw_SwJJf2IdpUO3u7lnBQac6oZEgzjYNMcQPKSp3bYDMa9axe-jf5b5JL7TEV0OC0WZ2IxeZU5a9LMoh5u1-bNr2z2bXsWpyIxIJ6si_cSpkSdPHBY0nN4zSwjrST-mReb2a9NFycUnqwyQrVJnHgxW5K19qMvQhXEd-cf-Hp3CIa-WKIllLXKHnQ7YMoWub4lg6M=&p=0&fvj=0&vjs=3',
#  'name': '\n\nHP'}

# %%
info[0]['title']
# Out:
# '\nArchitecture Data Scientist'

# %%
summaries = []
summary_links = [info[0]['summarylinks']]
base_url = 'https://www.indeed.com'
try:
    for tail in summary_links:
        link = base_url + tail
        page = requests.get(link)
        soup = BeautifulSoup(page.text, 'html.parser')
        div = soup.find_all('div', attrs={'id': 'jobDescriptionText'})
        summaries.append([link, div[0].text])
except IndexError:
    logger.error('Here\'s what div looks like\n:', div)
    logger.error('URL:', link)
df = pd.DataFrame(summaries, columns = ['links', 'description'])

# %%
# %load_ext autoreload
# %autoreload 2
from proxyManager import ProxyManager
proxy_list = ProxyManager(url='https://www.indeed.com/')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
proxy_list.proxies
# Out:
# no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '193.110.115.220:3128': {'country_code': 'UA',
#   'country': 'Ukraine',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '51.81.82.175:80': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '212.12.69.43:8080': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '118.99.108.16:8080': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '78.111.97.182:3142': {'country_code': 'TR',
#   'country': 'Turkey',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '177.10.193.91:55777': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.240.161.109:6666': {'country_code': 'IN',
#   'country': 'India',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '202.142.159.26:48970': {'country_code': 'PK',
#   'country': 'Pakistan',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '106.104.151.142:58198': {'country_code': 'TW',
#   'country': 'Taiwan',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '182.253.82.156:37242': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '197.248.7.229:8080': {'country_code': 'KE',
#   'country': 'Kenya',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '78.154.167.68:8080': {'country_code': 'UA',
#   'country': 'Ukraine',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.36.11.161:14571': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.100.96.174:55443': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '122.2.37.38:54444': {'country_code': 'PH',
#   'country': 'Philippines',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '104.211.29.96:80': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '193.149.225.181:80': {'country_code': 'GB',
#   'country': 'United Kingdom',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '86.2.68.122:80': {'country_code': 'GB',
#   'country': 'United Kingdom',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '179.108.123.210:51314': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '168.119.202.235:80': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '180.179.98.22:3128': {'country_code': 'IN',
#   'country': 'India',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '191.101.39.45:80': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '160.2.59.45:8080': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '162.208.48.84:8118': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '89.107.197.173:35615': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '47.75.90.57:80': {'country_code': 'HK',
#   'country': 'Hong Kong',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.92.225.98:55443': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '62.23.15.92:3128': {'country_code': 'FR',
#   'country': 'France',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '191.101.39.90:80': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '178.128.125.16:33017': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '213.105.29.14:3128': {'country_code': 'GB',
#   'country': 'United Kingdom',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '175.139.151.142:80': {'country_code': 'MY',
#   'country': 'Malaysia',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '168.119.202.236:80': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '108.30.209.198:80': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.240.206.152:55740': {'country_code': 'IN',
#   'country': 'India',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '68.94.189.60:80': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '34.93.251.92:80': {'country_code': 'IN',
#   'country': 'India',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '135.181.18.103:32377': {'country_code': 'FI',
#   'country': 'Finland',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '87.249.217.57:3128': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '182.253.69.34:8080': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '183.88.213.85:8080': {'country_code': 'TH',
#   'country': 'Thailand',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '62.91.90.130:8080': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '138.122.8.49:32717': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '93.117.72.27:43631': {'country_code': 'MD',
#   'country': 'Moldova, Republic of',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '91.230.199.174:61440': {'country_code': 'UA',
#   'country': 'Ukraine',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '181.189.221.209:61783': {'country_code': 'AR',
#   'country': 'Argentina',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '192.109.165.31:80': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '65.184.156.234:52981': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '89.223.80.30:8080': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '177.137.207.51:55443': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '168.119.202.234:80': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '122.254.86.250:8080': {'country_code': 'NP',
#   'country': 'Nepal',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '95.216.214.160:3128': {'country_code': 'FI',
#   'country': 'Finland',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '110.232.86.52:53281': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '193.239.86.136:3128': {'country_code': 'HK',
#   'country': 'Hong Kong',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '85.238.167.170:51915': {'country_code': 'AT',
#   'country': 'Austria',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '178.134.208.126:50824': {'country_code': 'GE',
#   'country': 'Georgia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '64.4.94.129:80': {'country_code': 'CA',
#   'country': 'Canada',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '37.228.65.107:32052': {'country_code': 'KZ',
#   'country': 'Kazakhstan',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '187.6.108.42:8080': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '124.158.167.170:8080': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '189.201.242.225:999': {'country_code': 'MX',
#   'country': 'Mexico',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '187.190.59.38:3128': {'country_code': 'MX',
#   'country': 'Mexico',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '101.109.16.152:8080': {'country_code': 'TH',
#   'country': 'Thailand',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '87.106.157.54:80': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '177.124.10.53:8080': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '189.80.3.187:8080': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '157.230.186.112:7777': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '119.42.105.135:8080': {'country_code': 'TH',
#   'country': 'Thailand',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '157.230.59.29:44331': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '185.23.131.101:8080': {'country_code': 'IR',
#   'country': 'Iran',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '1.32.59.217:47045': {'country_code': 'MY',
#   'country': 'Malaysia',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '103.112.163.245:8080': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '139.99.105.185:80': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '190.214.27.106:48586': {'country_code': 'EC',
#   'country': 'Ecuador',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '115.85.65.150:39736': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '189.14.193.242:53281': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '222.124.173.146:53281': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '139.5.71.70:23500': {'country_code': 'NP',
#   'country': 'Nepal',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '113.53.91.12:53281': {'country_code': 'TH',
#   'country': 'Thailand',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '68.183.191.77:8118': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '196.3.97.34:23500': {'country_code': 'MZ',
#   'country': 'Mozambique',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '191.101.39.47:80': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '125.141.117.9:80': {'country_code': 'KR',
#   'country': 'Korea',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '191.101.39.135:80': {'country_code': 'SG',
#   'country': 'Singapore',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '31.40.136.138:53281': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '49.12.2.178:3128': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '37.26.179.150:80': {'country_code': 'FR',
#   'country': 'France',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '95.111.134.122:32345': {'country_code': 'UA',
#   'country': 'Ukraine',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '54.151.3.183:8080': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '45.33.105.95:8118': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '83.167.203.174:50128': {'country_code': 'NL',
#   'country': 'Netherlands',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '216.58.163.118:80': {'country_code': 'US',
#   'country': 'United States',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.87.170.88:46898': {'country_code': 'IN',
#   'country': 'India',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '103.255.53.98:56031': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '165.22.81.30:46215': {'country_code': 'DE',
#   'country': 'Germany',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '58.69.161.161:8080': {'country_code': 'PH',
#   'country': 'Philippines',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '176.235.182.79:8080': {'country_code': 'TR',
#   'country': 'Turkey',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '52.78.75.87:80': {'country_code': 'KR',
#   'country': 'Korea',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '37.79.254.152:3128': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '77.232.167.200:47211': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '186.225.45.13:45974': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '79.143.225.152:60517': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '197.245.230.122:41026': {'country_code': 'ZA',
#   'country': 'South Africa',
#   'privacy': 'anonymous',
#   'google': 'no',
#   'https': 'yes',
#   'last_checked': None,
#   'alive': True},
#  '84.204.40.154:8080': {'country_code': 'RU',
#   'country': 'Russian Federation',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.56.235.186:443': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '190.53.46.2:44612': {'country_code': 'SV',
#   'country': 'El Salvador',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '182.253.173.238:8080': {'country_code': 'ID',
#   'country': 'Indonesia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '181.129.183.19:53281': {'country_code': 'CO',
#   'country': 'Colombia',
#   'privacy': 'elite proxy',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '103.119.244.10:55207': {'country_code': 'IN',
#   'country': 'India',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '177.184.148.253:8080': {'country_code': 'BR',
#   'country': 'Brazil',
#   'privacy': 'level3',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '164.77.175.246:46385': {'country_code': 'CL',
#   'country': 'Chile',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True},
#  '195.225.48.193:58302': {'country_code': 'UA',
#   'country': 'Ukraine',
#   'privacy': 'transparent',
#   'google': 'no',
#   'https': 'no',
#   'last_checked': None,
#   'alive': True}}

# %%
temp_info['title']
# Out:
# '\nData Scientist (Contract)'
