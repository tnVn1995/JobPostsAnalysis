# %% [markdown]
# # Job Postings Analysis
#
# What the job market for tech industry looks like during the pandemic? Covid-19 poses unparalled challenges for the US economy. How do tech companies deal with hiring during the pandemic? We'll analyze job postings from Indeed to see how the pandemic affects the job market in some states in the U.S.

# %%
import nltk
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF
import text_normalize as tn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jobInfo = pd.read_csv('data/IndeedJobPosts.csv')
jobDesc = pd.read_csv('data/JobDesc.csv')
jobDesc500 = jobDesc.iloc[:500,1:]
jobDesc500.head()
# Out:
#                                                                                                         links  \
# 0  https://www.indeed.com/company/GradTests/jobs/Data-Scientist-cb83495bc53e4cd0?fccid=3b57c72e54f9233d&vjs=3
# 1  https://www.indeed.com/rc/clk?jk=bddcb1faeb174b60&fccid=3c78581902185d47&vjs=3
# 2  https://www.indeed.com/rc/clk?jk=920503f4cad6ef57&fccid=228c7dfd08a45e32&vjs=3
# 3  https://www.indeed.com/rc/clk?jk=1e8835abdc7dfc2a&fccid=b4e04bf6950ab9ef&vjs=3
# 4  https://www.indeed.com/rc/clk?jk=5087da22d7255a30&fccid=3639654bd4055c70&vjs=3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             description
# 0  The BusinessGradTests.com is a leading provider of practice psychometric tests to graduates, students and young professionals.The RoleA data science all rounder role. The core purpose of the role is to build models to improve the product, the customer experience and ultimately the business. We're looking for someone with a nice blend of technical skills, and softer skills like business acumen, decision making and communication skills.You'll do things like:Conceive, devise, create, implement and fine tune data science models to solve a range of business problems, from customer churn through toSet up, run and analyse A/B experiments for the website and email marketing campaignsHelp devise and layout a high quality infrastructure, upon which future data science can flourishHelp up skill other analytical team members into advanced data science techniquesProduce ad hoc analysesAnd let's be honest, a whole load of data wrangling!Skills and experienceNon negotiables:SQLPython or RData science models (K-means, random Forrest, neural nets etc.)Strong foundational knowledge in stats and mathsExperience in actually productionising models and exposing to real customersBusiness acumenStrong communication skills, both written and verbalNice to haves:Experience in working with developers, especially on experimentationSome kind of cloud based experience (AWS preferred)Some basic knowledge of source control with GitOur application process consists of some online testing with Alooba, video call interview and then a case study. We expect the process to take about 10 business days end to end.Job Types: Full-time, ContractSalary: $120,000.00 /yearExperience:Analytics: 1 year (Preferred)Work Remotely:Yes
# 1  The RiceTec Data Scientist will need to Design strategies and implement algorithms to analyze and leverage data; assessing the effectiveness and accuracy of data sources to be used as inputs in data analysis; to implement visualization systems that make data readily available and simplify how insights are communicated.\n\nThis analysis will be used for detection of crop response to sync management techniques, fertilizers and other crop production inputs; development of crop and pest management aids based on aerial images in large production fields; validation of small plot data collected by aerial sensors with established ground-based information.\n\nAnalysis will also focus on identifying opportunities for new and existing weather models to create value in supply reliability; parent line production; crop management.\n\nResults should translate production problems into data-driven analytics / machine-learning tasks and building related products which automate the operational functions in production and manufacturing areas.\n\nCandidates should have experience in building advanced analytics models across one or more areas of Predictive/Prescriptive Analytics, and Image Processing; Expertise in analytical packages such as Python, R, Statistical packages like Statistica, Minitab; applied experience in various machine learning techniques (e.g. Neural Networks).\n\nRequirements: Masters in Statistics, Mathematics, Machine Learning, Agricultural Statistics or Climatology. PhD is Preferred.
# 2  Tokio Marine HCC is a leading specialty insurance group with offices in the United States, the United Kingdom, and Continental Europe, transacting business in approximately 180 countries and underwriting more than 100 classes of specialty insurance. Tokio Marine HCC products and capabilities set the standard for the industry, and many of the Company’s almost 3,000 employees are industry-leading experts.\n\nAre you currently seeking a challenging Data Scientist opportunity to help develop text analytics capabilities? At TMHCC, we have an exciting opportunity for a Data Scientist in our corporate office in Houston, TX. In this role, you will be a key member of the actuarial team to provide analytical support for the various underwriting units including, but not limited to, pricing and claims support, budget support, and providing key statistics on results to underwriting units. The work will be technical and analytical. The individual will be doing predictive and data analytics.\n\nPerformance Objective:\nApply your expertise to prepare internal and external, structured and unstructured data\nCollaborate with the actuarial team to develop text analytics capabilities\nDesign, build and validate models using simple and advanced modeling techniques to help business leaders quantify risks and make better decisions\nSupport cross-functional teams to implement models\nEffectively collaborate with business stakeholders across the organization to understand business processes and problems to develop effective analytical solutions\nDevelop monitoring solutions for business stakeholders after model implementations to monitor the accuracy of predictions, proper usage, and business impact\nExpectations:\nWithin the first 30 days, become familiar with TMHCC’s policies and procedures\nWithin the first 60 days, take ownership to develop text analytics capabilities\nQualifications:\nExperience with Natural Language Processing (Text Analytics)\nExperience with Python or “R” or similar data analysis programming language\nAbility to handle sensitive and/or confidential material strictly in accordance with company policy and legal requirements\nFlexibility to work outside of normal business hours and a willingness to learn\nSound analytical skills as well as problem-solving aptitude\nMust be an exceptional communicator and able to make connections across the organization\nEducational requirements: the ideal candidate will have a Master’s degree in Data Science, Computer Science, Actuarial Science, Mathematics, Statistics or related field, or the equivalent education and/or experience. A Ph.D. would be preferred.\nThe Tokio Marine HCC Group of Companies offer a competitive salary and employee benefit package. We are a successful, dynamic organization experiencing rapid growth and are seeking an energetic and confident individual to join our team of professionals. The Tokio Marine HCC Group of Companies are equal-opportunity employers. Please visit www.tmhcc.com for more information about our companies.\n\n#LI\n#GD\n#CB
# 3  Data Scientist – North America CoE\nThe Data Scientist is responsible for providing the delivery of Data and Analytics solutions to Techwave clients as part of our Data & Analytics CoE. The role will create solutions to business challenges through the use of advanced statistical analysis, data mining, and data visualization techniques.\nResponsibilities:\nIdentifies the data the business should be collecting, devises methods of instrumenting the business’s system in order to extract this information\nDesigns, implements, and evaluates advanced statistical models and approaches for application in the business’s most complex issues\nConduct software development, software integration, statistical analysis, modeling, and simulations in a rapid DevOps environment.\nDeploy new data science capabilities through existing toolsets.\nCleansing of large unstructured data and enabling analytical capability in order to query the data and address various business needs\nTakes initiative to experiment with various technologies and tools with vision of creating innovative data driven insights for the business at the quickest pace possible.\nStaying on top of the industry’s trends, in order to provide forward-thinking recommendations\n.\nRequirements:\nPh.D. or Masters with experience in any mathematical sciences\nStrong programming skills and experience working with tools such as R, Python Programming, Open Source, visualizations, and so forth.\nDemonstrated skills in SQL server reporting services, analysis services, integration services, Tableau, or other data visualization tools.\nStrong skill in statistical techniques inclusive of cluster-analysis test design, regressions, and forecasting methodologies as well as substantial familiarity in big data and standardizing and A/B testing.\nExperience cleaning labeled data in preparation for use in machine learning\nAbility to create parallel processing operations by managing the number of processors used in an operation given memory limitations\nKnowledge of cloud based data platforms such as Snowflake, Redshift, BigQuery etc..
# 4  Houston\nTexas\n18081BR\nJob Summary\nBDO’s Core Purpose is Helping People Thrive Every Day. Our Core Values reflect how we manage our work, our relationships and ourselves. As an employee of the firm, you will live true to our Core Values of people first, being exceptional every day in every way, embracing change, feeling empowered through knowledge and choosing accountability. Our Core Values are the standards by which we conduct ourselves day in and day out, both internally and externally.\n\nBDO Digital, LLC, a subsidiary of BDO USA, LLP, provides a holistic portfolio of technology, transformation services and solutions. We are an organization that values your time, talent, and contributions. Collaborate with BDO Digital’s cross-disciplinary team who work together to solve digital needs and unearth new opportunities to drive competitive advantage. Our commitment to each other is why BDO Digital is a recognized leader for our culture, employee satisfaction and career growth. We’re looking for people with the same drive; to combine teamwork with technology to produce amazing results.\n\nThis role will work with cutting-edge technologies within the cloud developing code in a collaborative team environment. This position will report to a Principal Software Consultant. This internship consists of real world projects and deliverables that will give you exposure to a variety of technologies from a variety of industries. You will have the opportunity to work on client projects that have a real business impact and give you the experience and skills to equip you in your future career. There is also the potential to join our team as a full-time employee after graduation.\n\nResponsibilities:\n\nTraining with Application Development: You will begin with an intensive, two-week course in hands-on web-based development, primarily based on Microsoft technologies, including Microsoft .NET and SQL ServerConsulting: Consulting is different than an internal role! You will gain an understanding of client differing needs and play a part in working on practical solutions to meet client expectationsBusiness Requirements Consumption: You will gain the ability to "speak both tech and business" by developing a deeper understanding of written and verbal business requirements provided by team Business Analysts and developersImplementation and Support: You'll be able to assist with software development projects and ongoing software supportOther duties as required\nQualifications\nEducation:\nCurrently attending an accredited college or university, majoring in Computer Science or related field, requiredAcademically in good standing with a cumulative GPA of at least 3.0, requiredCurrently an actively enrolled Junior / Senior student, required\nExperience:\nFour (4) or more months programming experience with any technology such as ASP.Net, C#, Java, SQL and SQL server, requiredClassroom programming experience, required\nSoftware:\nExperience with one or more of the following required:\nASP.Net, .Net, C# or MVCJavaSQL\nOther Knowledge, Skills & Abilities:\nMust be living locally within the Houston area and able to work from our Houston officeAble to work a minimum of 20-25 hours a week for 8-12-week period (we can be flexible around your schedule)\nKeywords: Intern, Software, Application, Java, C#, .Net, ASP.Net, Microsoft, Development, SQL, VB.Net, PHP, Visual Studio, SharePoint

# %%
display(jobInfo.head())
jobInfo.summarylinks = 'https://www.indeed.com' + jobInfo['summarylinks']
display(jobInfo.head())
# Out:
#    Unnamed: 0                                                        title  \
# 0  0           Data Scientist
# 1  1           Data Scientist - Production Research
# 2  2           Data Scientist
# 3  3           Data Scientist
# 4  4           Software Developer Intern (Data Analytics Team) - Fall 2020
#
#                                                                            summarylinks  \
# 0  /company/GradTests/jobs/Data-Scientist-cb83495bc53e4cd0?fccid=3b57c72e54f9233d&vjs=3
# 1  /rc/clk?jk=bddcb1faeb174b60&fccid=3c78581902185d47&vjs=3
# 2  /rc/clk?jk=920503f4cad6ef57&fccid=228c7dfd08a45e32&vjs=3
# 3  /rc/clk?jk=1e8835abdc7dfc2a&fccid=b4e04bf6950ab9ef&vjs=3
# 4  /rc/clk?jk=5087da22d7255a30&fccid=3639654bd4055c70&vjs=3
#
#                         name  \
# 0  GradTests (gradtests.com)
# 1  RiceTec, Inc.
# 2  Tokio Marine HCC
# 3  Techwave Consulting Inc.
# 4  BDO
#
#                                                   location
# 0  Houston, TX
# 1  Alvin, TX
# 2  Houston, TX 77040 (Fairbanks - Northwest Crossing area)
# 3  Houston, TX 77077
# 4  Houston, TX 77019 (Neartown - Montrose area)
#    Unnamed: 0                                                        title  \
# 0  0           Data Scientist
# 1  1           Data Scientist - Production Research
# 2  2           Data Scientist
# 3  3           Data Scientist
# 4  4           Software Developer Intern (Data Analytics Team) - Fall 2020
#
#                                                                                                  summarylinks  \
# 0  https://www.indeed.com/company/GradTests/jobs/Data-Scientist-cb83495bc53e4cd0?fccid=3b57c72e54f9233d&vjs=3
# 1  https://www.indeed.com/rc/clk?jk=bddcb1faeb174b60&fccid=3c78581902185d47&vjs=3
# 2  https://www.indeed.com/rc/clk?jk=920503f4cad6ef57&fccid=228c7dfd08a45e32&vjs=3
# 3  https://www.indeed.com/rc/clk?jk=1e8835abdc7dfc2a&fccid=b4e04bf6950ab9ef&vjs=3
# 4  https://www.indeed.com/rc/clk?jk=5087da22d7255a30&fccid=3639654bd4055c70&vjs=3
#
#                         name  \
# 0  GradTests (gradtests.com)
# 1  RiceTec, Inc.
# 2  Tokio Marine HCC
# 3  Techwave Consulting Inc.
# 4  BDO
#
#                                                   location
# 0  Houston, TX
# 1  Alvin, TX
# 2  Houston, TX 77040 (Fairbanks - Northwest Crossing area)
# 3  Houston, TX 77077
# 4  Houston, TX 77019 (Neartown - Montrose area)

# %%
# Merge dataframes
mergedDf = jobInfo.merge(jobDesc, left_on='summarylinks', right_on='links')
mergedDf.head()
# Out:
#    Unnamed: 0_x                                                        title  \
# 0  0             Data Scientist
# 1  1             Data Scientist - Production Research
# 2  2             Data Scientist
# 3  3             Data Scientist
# 4  4             Software Developer Intern (Data Analytics Team) - Fall 2020
#
#                                                                                                  summarylinks  \
# 0  https://www.indeed.com/company/GradTests/jobs/Data-Scientist-cb83495bc53e4cd0?fccid=3b57c72e54f9233d&vjs=3
# 1  https://www.indeed.com/rc/clk?jk=bddcb1faeb174b60&fccid=3c78581902185d47&vjs=3
# 2  https://www.indeed.com/rc/clk?jk=920503f4cad6ef57&fccid=228c7dfd08a45e32&vjs=3
# 3  https://www.indeed.com/rc/clk?jk=1e8835abdc7dfc2a&fccid=b4e04bf6950ab9ef&vjs=3
# 4  https://www.indeed.com/rc/clk?jk=5087da22d7255a30&fccid=3639654bd4055c70&vjs=3
#
#                         name  \
# 0  GradTests (gradtests.com)
# 1  RiceTec, Inc.
# 2  Tokio Marine HCC
# 3  Techwave Consulting Inc.
# 4  BDO
#
#                                                   location  Unnamed: 0_y  \
# 0  Houston, TX                                              0
# 1  Alvin, TX                                                1
# 2  Houston, TX 77040 (Fairbanks - Northwest Crossing area)  2
# 3  Houston, TX 77077                                        3
# 4  Houston, TX 77019 (Neartown - Montrose area)             4
#
#                                                                                                         links  \
# 0  https://www.indeed.com/company/GradTests/jobs/Data-Scientist-cb83495bc53e4cd0?fccid=3b57c72e54f9233d&vjs=3
# 1  https://www.indeed.com/rc/clk?jk=bddcb1faeb174b60&fccid=3c78581902185d47&vjs=3
# 2  https://www.indeed.com/rc/clk?jk=920503f4cad6ef57&fccid=228c7dfd08a45e32&vjs=3
# 3  https://www.indeed.com/rc/clk?jk=1e8835abdc7dfc2a&fccid=b4e04bf6950ab9ef&vjs=3
# 4  https://www.indeed.com/rc/clk?jk=5087da22d7255a30&fccid=3639654bd4055c70&vjs=3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             description
# 0  The BusinessGradTests.com is a leading provider of practice psychometric tests to graduates, students and young professionals.The RoleA data science all rounder role. The core purpose of the role is to build models to improve the product, the customer experience and ultimately the business. We're looking for someone with a nice blend of technical skills, and softer skills like business acumen, decision making and communication skills.You'll do things like:Conceive, devise, create, implement and fine tune data science models to solve a range of business problems, from customer churn through toSet up, run and analyse A/B experiments for the website and email marketing campaignsHelp devise and layout a high quality infrastructure, upon which future data science can flourishHelp up skill other analytical team members into advanced data science techniquesProduce ad hoc analysesAnd let's be honest, a whole load of data wrangling!Skills and experienceNon negotiables:SQLPython or RData science models (K-means, random Forrest, neural nets etc.)Strong foundational knowledge in stats and mathsExperience in actually productionising models and exposing to real customersBusiness acumenStrong communication skills, both written and verbalNice to haves:Experience in working with developers, especially on experimentationSome kind of cloud based experience (AWS preferred)Some basic knowledge of source control with GitOur application process consists of some online testing with Alooba, video call interview and then a case study. We expect the process to take about 10 business days end to end.Job Types: Full-time, ContractSalary: $120,000.00 /yearExperience:Analytics: 1 year (Preferred)Work Remotely:Yes
# 1  The RiceTec Data Scientist will need to Design strategies and implement algorithms to analyze and leverage data; assessing the effectiveness and accuracy of data sources to be used as inputs in data analysis; to implement visualization systems that make data readily available and simplify how insights are communicated.\n\nThis analysis will be used for detection of crop response to sync management techniques, fertilizers and other crop production inputs; development of crop and pest management aids based on aerial images in large production fields; validation of small plot data collected by aerial sensors with established ground-based information.\n\nAnalysis will also focus on identifying opportunities for new and existing weather models to create value in supply reliability; parent line production; crop management.\n\nResults should translate production problems into data-driven analytics / machine-learning tasks and building related products which automate the operational functions in production and manufacturing areas.\n\nCandidates should have experience in building advanced analytics models across one or more areas of Predictive/Prescriptive Analytics, and Image Processing; Expertise in analytical packages such as Python, R, Statistical packages like Statistica, Minitab; applied experience in various machine learning techniques (e.g. Neural Networks).\n\nRequirements: Masters in Statistics, Mathematics, Machine Learning, Agricultural Statistics or Climatology. PhD is Preferred.
# 2  Tokio Marine HCC is a leading specialty insurance group with offices in the United States, the United Kingdom, and Continental Europe, transacting business in approximately 180 countries and underwriting more than 100 classes of specialty insurance. Tokio Marine HCC products and capabilities set the standard for the industry, and many of the Company’s almost 3,000 employees are industry-leading experts.\n\nAre you currently seeking a challenging Data Scientist opportunity to help develop text analytics capabilities? At TMHCC, we have an exciting opportunity for a Data Scientist in our corporate office in Houston, TX. In this role, you will be a key member of the actuarial team to provide analytical support for the various underwriting units including, but not limited to, pricing and claims support, budget support, and providing key statistics on results to underwriting units. The work will be technical and analytical. The individual will be doing predictive and data analytics.\n\nPerformance Objective:\nApply your expertise to prepare internal and external, structured and unstructured data\nCollaborate with the actuarial team to develop text analytics capabilities\nDesign, build and validate models using simple and advanced modeling techniques to help business leaders quantify risks and make better decisions\nSupport cross-functional teams to implement models\nEffectively collaborate with business stakeholders across the organization to understand business processes and problems to develop effective analytical solutions\nDevelop monitoring solutions for business stakeholders after model implementations to monitor the accuracy of predictions, proper usage, and business impact\nExpectations:\nWithin the first 30 days, become familiar with TMHCC’s policies and procedures\nWithin the first 60 days, take ownership to develop text analytics capabilities\nQualifications:\nExperience with Natural Language Processing (Text Analytics)\nExperience with Python or “R” or similar data analysis programming language\nAbility to handle sensitive and/or confidential material strictly in accordance with company policy and legal requirements\nFlexibility to work outside of normal business hours and a willingness to learn\nSound analytical skills as well as problem-solving aptitude\nMust be an exceptional communicator and able to make connections across the organization\nEducational requirements: the ideal candidate will have a Master’s degree in Data Science, Computer Science, Actuarial Science, Mathematics, Statistics or related field, or the equivalent education and/or experience. A Ph.D. would be preferred.\nThe Tokio Marine HCC Group of Companies offer a competitive salary and employee benefit package. We are a successful, dynamic organization experiencing rapid growth and are seeking an energetic and confident individual to join our team of professionals. The Tokio Marine HCC Group of Companies are equal-opportunity employers. Please visit www.tmhcc.com for more information about our companies.\n\n#LI\n#GD\n#CB
# 3  Data Scientist – North America CoE\nThe Data Scientist is responsible for providing the delivery of Data and Analytics solutions to Techwave clients as part of our Data & Analytics CoE. The role will create solutions to business challenges through the use of advanced statistical analysis, data mining, and data visualization techniques.\nResponsibilities:\nIdentifies the data the business should be collecting, devises methods of instrumenting the business’s system in order to extract this information\nDesigns, implements, and evaluates advanced statistical models and approaches for application in the business’s most complex issues\nConduct software development, software integration, statistical analysis, modeling, and simulations in a rapid DevOps environment.\nDeploy new data science capabilities through existing toolsets.\nCleansing of large unstructured data and enabling analytical capability in order to query the data and address various business needs\nTakes initiative to experiment with various technologies and tools with vision of creating innovative data driven insights for the business at the quickest pace possible.\nStaying on top of the industry’s trends, in order to provide forward-thinking recommendations\n.\nRequirements:\nPh.D. or Masters with experience in any mathematical sciences\nStrong programming skills and experience working with tools such as R, Python Programming, Open Source, visualizations, and so forth.\nDemonstrated skills in SQL server reporting services, analysis services, integration services, Tableau, or other data visualization tools.\nStrong skill in statistical techniques inclusive of cluster-analysis test design, regressions, and forecasting methodologies as well as substantial familiarity in big data and standardizing and A/B testing.\nExperience cleaning labeled data in preparation for use in machine learning\nAbility to create parallel processing operations by managing the number of processors used in an operation given memory limitations\nKnowledge of cloud based data platforms such as Snowflake, Redshift, BigQuery etc..
# 4  Houston\nTexas\n18081BR\nJob Summary\nBDO’s Core Purpose is Helping People Thrive Every Day. Our Core Values reflect how we manage our work, our relationships and ourselves. As an employee of the firm, you will live true to our Core Values of people first, being exceptional every day in every way, embracing change, feeling empowered through knowledge and choosing accountability. Our Core Values are the standards by which we conduct ourselves day in and day out, both internally and externally.\n\nBDO Digital, LLC, a subsidiary of BDO USA, LLP, provides a holistic portfolio of technology, transformation services and solutions. We are an organization that values your time, talent, and contributions. Collaborate with BDO Digital’s cross-disciplinary team who work together to solve digital needs and unearth new opportunities to drive competitive advantage. Our commitment to each other is why BDO Digital is a recognized leader for our culture, employee satisfaction and career growth. We’re looking for people with the same drive; to combine teamwork with technology to produce amazing results.\n\nThis role will work with cutting-edge technologies within the cloud developing code in a collaborative team environment. This position will report to a Principal Software Consultant. This internship consists of real world projects and deliverables that will give you exposure to a variety of technologies from a variety of industries. You will have the opportunity to work on client projects that have a real business impact and give you the experience and skills to equip you in your future career. There is also the potential to join our team as a full-time employee after graduation.\n\nResponsibilities:\n\nTraining with Application Development: You will begin with an intensive, two-week course in hands-on web-based development, primarily based on Microsoft technologies, including Microsoft .NET and SQL ServerConsulting: Consulting is different than an internal role! You will gain an understanding of client differing needs and play a part in working on practical solutions to meet client expectationsBusiness Requirements Consumption: You will gain the ability to "speak both tech and business" by developing a deeper understanding of written and verbal business requirements provided by team Business Analysts and developersImplementation and Support: You'll be able to assist with software development projects and ongoing software supportOther duties as required\nQualifications\nEducation:\nCurrently attending an accredited college or university, majoring in Computer Science or related field, requiredAcademically in good standing with a cumulative GPA of at least 3.0, requiredCurrently an actively enrolled Junior / Senior student, required\nExperience:\nFour (4) or more months programming experience with any technology such as ASP.Net, C#, Java, SQL and SQL server, requiredClassroom programming experience, required\nSoftware:\nExperience with one or more of the following required:\nASP.Net, .Net, C# or MVCJavaSQL\nOther Knowledge, Skills & Abilities:\nMust be living locally within the Houston area and able to work from our Houston officeAble to work a minimum of 20-25 hours a week for 8-12-week period (we can be flexible around your schedule)\nKeywords: Intern, Software, Application, Java, C#, .Net, ASP.Net, Microsoft, Development, SQL, VB.Net, PHP, Visual Studio, SharePoint

# %% [markdown]
# ## New Tech Jobs by State
#
# We'll analyze the current job market by state in tech industry

# %% [markdown]
# ### Job Types by State

# %%
import re
locs = mergedDf.location.unique()
states = {'TX':[], 'NY':[],'PA':[], 'CA':[], 'MA':[],'DC':[]}
for state in states:                        
    pattern = re.compile(state)
    for idx, x in enumerate(locs):
        if re.search(pattern, x):
            states[state].append(idx)

NY = mergedDf.iloc[states['NY'],:]
TX = mergedDf.iloc[states['TX'],:]
PA = mergedDf.iloc[states['PA'],:]
CA = mergedDf.iloc[states['CA'],:]
MA = mergedDf.iloc[states['MA'],:]
DC = mergedDf.iloc[states['DC'],:]
States = [NY, TX, PA, MA, DC]
no_jobs = [len(x) for x in States]
# Distribution of new jobs by State
plt.bar([0,1,2,3,4],no_jobs)
plt.xticks([0,1,2,3,4],list(states.keys()))
plt.title('Job Distribution by States', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Job Distribution by States')

# %% [markdown]
# ### Job Post Analysis by State
#
# One way to see the trend in job market by state is to analyze the job descriptions in each state. The following sections perform non-negative matrix factorization to extract important topics from job postings by three states NY, CA, PA.

# %% [markdown]
# Before performing text analysis, we need to perform preprocessing of text (remove stopwords, lemmatize, remove accented words,
# Tokenize etc) and transform them in numeric form as computers do not understand words.

# %%
# %time
# Parallel processing
# The scripts are in text_normalize.py
NY_corpus = tn.parallel_normalize_corpus(NY.description.values)
CA_corpus = tn.parallel_normalize_corpus(TX.description.values)
PA_corpus = tn.parallel_normalize_corpus(PA.description.values)
# Out:
# Wall time: 0 ns
# Took 9.9115 seconds with 6 process(es).
# Took 12.0147 seconds with 6 process(es).
# Took 10.2670 seconds with 6 process(es).

# %%
corpuses = {'NY':NY_corpus, 'DC':DC_corpus, 'CA':CA_corpus}
norm_corpus = {}
# Tokernize text corpus
for state, corpus in corpuses.items():
     norm_corpus[state] = [x.split(' ') for x in corpus]

# %% [markdown]
# Here's the text corpus after preprocessing

# %%
print(len(norm_corpus))
print(norm_corpus['CA'][:50])
# Out:
# 3
# [['businessgradtests', 'com', 'lead', 'provider', 'practice', 'psychometric', 'test', 'graduate', 'student', 'young', 'professionals', 'rolea', 'datum', 'science', 'rounder', 'role', 'core', 'purpose', 'role', 'build', 'model', 'improve', 'product', 'customer', 'experience', 'ultimately', 'business', 'look', 'someone', 'nice', 'blend', 'technical', 'skill', 'soft', 'skill', 'like', 'business', 'acuman', 'decision', 'making', 'communication', 'skills', 'thing', 'like', 'conceive', 'devise', 'create', 'implement', 'fine', 'tune', 'datum', 'science', 'model', 'solve', 'range', 'business', 'problem', 'customer', 'churn', 'toset', 'run', 'analyse', 'b', 'experiment', 'website', 'email', 'marketing', 'campaignshelp', 'devise', 'layout', 'high', 'quality', 'infrastructure', 'upon', 'future', 'datum', 'science', 'flourishhelp', 'skill', 'analytical', 'team', 'member', 'advanced', 'datum', 'science', 'techniquesproduce', 'ad', 'hoc', 'analysesand', 'let', 'us', 'honest', 'whole', 'load', 'datum', 'wrangling', 'skills', 'experiencenon', 'negotiables', 'sqlpython', 'rdata', 'science', 'model', 'k', 'means', 'random', 'forrest', 'neural', 'net', 'etc', 'strong', 'foundational', 'knowledge', 'stat', 'mathsexperience', 'actually', 'productionise', 'model', 'expose', 'real', 'customersbusiness', 'acumenstrong', 'communication', 'skill', 'write', 'verbalnice', 'experience', 'work', 'developer', 'especially', 'experimentationsome', 'kind', 'cloud', 'base', 'experience', 'aws', 'preferred', 'basic', 'knowledge', 'source', 'control', 'gitour', 'application', 'process', 'consist', 'online', 'testing', 'alooba', 'video', 'call', 'interview', 'case', 'study', 'expect', 'process', 'take', 'business', 'day', 'end', 'end', 'job', 'type', 'full', 'time', 'contractsalary', 'yearexperience', 'analytic', 'year', 'preferred', 'work', 'remotely', 'yes'], ['ricetec', 'data', 'scientist', 'need', 'design', 'strategy', 'implement', 'algorithm', 'analyze', 'leverage', 'datum', 'assess', 'effectiveness', 'accuracy', 'datum', 'source', 'use', 'input', 'datum', 'analysis', 'implement', 'visualization', 'system', 'make', 'datum', 'readily', 'available', 'simplify', 'insight', 'communicate', 'analysis', 'use', 'detection', 'crop', 'response', 'sync', 'management', 'technique', 'fertilizer', 'crop', 'production', 'input', 'development', 'crop', 'pest', 'management', 'aids', 'base', 'aerial', 'image', 'large', 'production', 'field', 'validation', 'small', 'plot', 'datum', 'collect', 'aerial', 'sensor', 'establish', 'ground', 'base', 'information', 'analysis', 'also', 'focus', 'identify', 'opportunity', 'new', 'existing', 'weather', 'model', 'create', 'value', 'supply', 'reliability', 'parent', 'line', 'production', 'crop', 'management', 'result', 'translate', 'production', 'problem', 'datum', 'drive', 'analytic', 'machine', 'learn', 'task', 'build', 'related', 'product', 'automate', 'operational', 'function', 'production', 'manufacturing', 'area', 'candidate', 'experience', 'build', 'advanced', 'analytic', 'model', 'across', 'one', 'area', 'predictive', 'prescriptive', 'analytic', 'image', 'processing', 'expertise', 'analytical', 'package', 'python', 'r', 'statistical', 'package', 'like', 'statistica', 'minitab', 'applied', 'experience', 'various', 'machine', 'learning', 'technique', 'e', 'g', 'neural', 'network', 'requirement', 'master', 'statistic', 'mathematic', 'machine', 'learning', 'agricultural', 'statistic', 'climatology', 'phd', 'prefer'], ['tokio', 'marine', 'hcc', 'lead', 'specialty', 'insurance', 'group', 'office', 'united', 'states', 'united', 'kingdom', 'continental', 'europe', 'transact', 'business', 'approximately', 'country', 'underwrite', 'class', 'specialty', 'insurance', 'tokio', 'marine', 'hcc', 'product', 'capability', 'set', 'standard', 'industry', 'many', 'companys', 'almost', 'employee', 'industry', 'lead', 'expert', 'currently', 'seek', 'challenge', 'data', 'scientist', 'opportunity', 'help', 'develop', 'text', 'analytic', 'capability', 'tmhc ...

# %% [markdown]
# #### Job Trend in NY

# %% [markdown]
# We'll perform feature engineering with tf-idf while removing terms that appear in fewer than 5 documents and more than 60% of the document. The reason is that these terms either are too specific or overgeneralized that they fail to capture the essential trend in the job market

# %%
# Feature Engineering
cv = CountVectorizer(min_df=5, max_df=0.6, ngram_range=(1,2),
                    token_pattern=None, tokenizer=lambda doc: doc,
                    preprocessor=lambda doc: doc)

cv_features = cv.fit_transform(norm_corpus['NY'])
cv_features.shape
# Out:
# (81, 987)

# %%
vocabulary = np.array(cv.get_feature_names())
print('Total Vocabulary Size:', len(vocabulary))
Total_Topic = 6
nmf_model = NMF(n_components=Total_Topic, solver='cd', max_iter=500,
               random_state=42, alpha=.1, l1_ratio=.85)

document_topics = nmf_model.fit_transform(cv_features)
# Out:
# Total Vocabulary Size: 987

# %%
topic_terms = nmf_model.components_
topic_key_term_idxs = np.argsort(-np.absolute(topic_terms), axis=1)[:,:20]
topic_keyterms = vocabulary[topic_key_term_idxs]
topics = [', '.join(topic) for topic in topic_keyterms]
pd.set_option('display.max_colwidth', -1)
topics_df = pd.DataFrame(topics, columns = ['Terms per Topic'], index = ['Topic' + str(t) for t in range(1,Total_Topic+1)])
topics_df
# Out:
#                                                                                                                                                                                                         Terms per Topic
# Topic1  project, support, provide, analysis, report, analyst, information, job, financial, system, company, forecast, sale, operation, need, customer, opportunity, planning, across, excel
# Topic2  sachs, goldman, goldman sachs, risk, firm, engineering, financial, client, investment, global, new, world, group, make, responsibility, division, build, change, solution, qualification
# Topic3  require, program, perform, ability, may, andor, staff, appropriate, need, use, make, client, time, duty, people, carry, training, change, maintain, report
# Topic4  test, testing, requirement, software, design, case, ability, write, quality, test case, system, development, ensure, client, use, technical, solution, knowledge, product, job
# Topic5  solution, technical, help, year, support, service, system, design, credit, problem, develop, organization, year experience, implement, identify, user, technology, financial, design develop, technical support
# Topic6  network, customer, service, technical, engineer, learning, develop, world, development, new, role, people, strong, candidate, etc, opportunity, program, company, tool, technology

# %% [markdown]
# At first glance, some popular topics are finance, maintenance, implementation, etc. The topic analysis shows that at the moment, tech jobs in NY revolves around the finance field with report, analysis, developing, testing and engineering skills on high demand

# %% [markdown]
# #### Job Trend in PA

# %%
cv = CountVectorizer(min_df=5, max_df=0.6, ngram_range=(1,2),
                    token_pattern=None, tokenizer=lambda doc: doc,
                    preprocessor=lambda doc: doc)

cv_features = cv.fit_transform(norm_corpus['PA'])
cv_features.shape
# Out:
# (130, 1358)

# %%
vocabulary = np.array(cv.get_feature_names())
print('Total Vocabulary Size:', len(vocabulary))
Total_Topic = 6
nmf_model = NMF(n_components=Total_Topic, solver='cd', max_iter=500,
               random_state=42, alpha=.1, l1_ratio=.85)

document_topics = nmf_model.fit_transform(cv_features)
# Out:
# Total Vocabulary Size: 1358

# %%
topic_terms = nmf_model.components_
topic_key_term_idxs = np.argsort(-np.absolute(topic_terms), axis=1)[:,:20]
topic_keyterms = vocabulary[topic_key_term_idxs]
topics = [', '.join(topic) for topic in topic_keyterms]
pd.set_option('display.max_colwidth', -1)
topics_df = pd.DataFrame(topics, columns = ['Terms per Topic'], index = ['Topic' + str(t) for t in range(1,Total_Topic+1)])
topics_df
# Out:
#                                                                                                                                                                                     Terms per Topic
# Topic1  software, design, application, development, develop, use, technology, system, client, knowledge, web, digital, code, solution, skill, computer, product, environment, new, user
# Topic2  engineering, must, require, position, document, may, engineer, professional, include, education, copy, requirement, provide, submit, program, note, service, information, applicant, agency
# Topic3  datum, big, analytic, business, solution, decision, include, good, job, development, skill, technical, use, management, problem, science, make, learn, new, tool
# Topic4  customer, service, microsoft, support, technology, project, business, technical, solution, product, role, skill, opportunity, partner, manager, provide, problem, lead, engineer, drive
# Topic5  support, service, client, ticket, technical, information, specialist, ability, provide, executive, operation, request, group, job, business, need, include, issue, hour, system
# Topic6  ability, employee, include, perform, job, opportunity, environment, provide, must, require, report, employment, duty, training, company, process, datum, skill, medical, program

# %% [markdown]
# SOme dominant terms are bigdata, system, maintenance, costumer, analysis, engineering, medical. The topic also shows that engineering jobs are on high demand. However, the job market in PA is more diverse (it includes jobs more customer-oriented and also jobs in medical field) as compared to the NY one where it's more finance-oriented.

# %% [markdown]
# #### Job Trend in CA

# %%
# 
cv = CountVectorizer(min_df=5, max_df=0.6, ngram_range=(1,2),
                    token_pattern=None, tokenizer=lambda doc: doc,
                    preprocessor=lambda doc: doc)

cv_features = cv.fit_transform(norm_corpus['CA'])
cv_features.shape
# Out:
# (168, 1688)

# %%
vocabulary = np.array(cv.get_feature_names())
print('Total Vocabulary Size:', len(vocabulary))
Total_Topic = 6
nmf_model = NMF(n_components=Total_Topic, solver='cd', max_iter=500,
               random_state=42, alpha=.1, l1_ratio=.85)

document_topics = nmf_model.fit_transform(cv_features)
# Out:
# Total Vocabulary Size: 1688

# %%
topic_terms = nmf_model.components_
topic_key_term_idxs = np.argsort(-np.absolute(topic_terms), axis=1)[:,:20]
topic_keyterms = vocabulary[topic_key_term_idxs]
topics = [', '.join(topic) for topic in topic_keyterms]
pd.set_option('display.max_colwidth', -1)
topics_df = pd.DataFrame(topics, columns = ['Terms per Topic'], index = ['Topic' + str(t) for t in range(1,Total_Topic+1)])
topics_df
# Out:
#                                                                                                                                                                                            Terms per Topic
# Topic1  solution, project, client, management, large, design, customer, technical, application, business, requirement, provide, identify, support, infrastructure, help, base, industry, automation, asset
# Topic2  system, perform, critical, maintenance, include, operation, equipment, center, require, job, employee, electrical, engineer, preferred, datum, control, may, duty, safety, environment
# Topic3  quality, project, must, management, ensure, support, process, able, knowledge, activity, implementation, plan, system, vision, must able, validation, within, engineering, manager, assign
# Topic4  scheduling, employee, department, schedule, staff, need, job, ensure, system, patient, care, service, position, report, time, communicate, within, daily, customer, manager
# Topic5  software, design, application, development, system, technology, develop, engineering, program, problem, environment, computer, product, web, solve, programming, knowledge, user, c, full
# Topic6  business, datum, ability, support, analysis, process, report, provide, financial, customer, analyst, use, sale, opportunity, strong, product, communication, company, service, management

# %% [markdown]
# The dominant terms are solution, client, maintenance, project, staff, communicate, product, business, engineering. Unlike the previous two states, businesses in CA are known to be highly tech-oriented. As such, jobs in CA gear more towards working among teams and satisfaction with customers.

# %% [markdown]
# ## Conclusion
#
# The analysis was performed on job postings scraped from Indeed for NY, PA, MA, CA, TX. Job postings in NY, CA, TX were analyzed using text analytics technique. Across various job titles in tech industry, the demand for skills in engineering, communicating are on the rise. Job seekers with financial background and engineering should apply in NY. While those with combination of skills in engineering, customer services should apply in PA, those with strong engineering background should apply in CA.
